# %%
# import required libs
import pickle
import numpy as np
import tensorflow as tf
from matplotlib import pyplot as plt
from tensorflow.keras import Sequential
from tensorflow.keras import layers

# %%
# load previously saved preprocessed data
X = pickle.load(open('X.pkl', 'rb')) # rb = read in binary
y = pickle.load(open('y.pkl', 'rb'))

# %%
len(X)
# Out:
# 25000

# %%
X
# Out:
# array([[[[ 24,  26,  27],
#          [ 24,  26,  27],
#          [ 25,  27,  28],
#          ...,
#          [ 55,  62,  61],
#          [ 54,  62,  64],
#          [ 54,  61,  64]],
#
#         [[ 24,  26,  27],
#          [ 24,  26,  27],
#          [ 25,  27,  28],
#          ...,
#          [ 52,  64,  65],
#          [ 52,  63,  64],
#          [ 53,  61,  59]],
#
#         [[ 25,  27,  28],
#          [ 25,  27,  28],
#          [ 25,  27,  28],
#          ...,
#          [ 59,  69,  63],
#          [ 60,  65,  55],
#          [ 54,  60,  55]],
#
#         ...,
#
#         [[ 28,  18,  30],
#          [ 31,  21,  34],
#          [ 31,  19,  37],
#          ...,
#          [ 33,  19,  37],
#          [ 33,  19,  37],
#          [ 33,  20,  36]],
#
#         [[ 27,  20,  25],
#          [ 29,  18,  34],
#          [ 29,  19,  32],
#          ...,
#          [ 28,  17,  33],
#          [ 32,  22,  34],
#          [ 32,  22,  35]],
#
#         [[ 27,  20,  25],
#          [ 29,  18,  34],
#          [ 29,  19,  32],
#          ...,
#          [ 28,  17,  33],
#          [ 30,  20,  32],
#          [ 30,  20,  33]]],
#
#
#        [[[217, 221, 215],
#          [218, 222, 216],
#          [216, 220, 214],
#          ...,
#          [ 40,  57,  76],
#          [ 21,  33,  66],
#          [  5,  17,  51]],
#
#         [[215, 219, 214],
#          [217, 222, 217],
#          [220, 224, 219],
#          ...,
#          [ 65,  83,  95],
#          [ 54,  67,  90],
#          [ 14,  25,  57]],
#
#         [[207, 210, 208],
#          [212, 215, 213],
#          [220, 223, 221],
#          ...,
#          [ 69,  85,  96],
#          [ 65,  80,  96],
#          [ 57,  68,  95]],
#
#         ...,
#
#         [[ 74,  45, 108],
#          [ 76,  47, 110],
#          [ 74,  46, 108],
#          ...,
#          [ 61,  37,  91],
#          [ 57,  33,  87],
#          [ 48,  27,  76]],
#
#         [[ 85,  57, 117],
#          [ 83,  55, 115],
#          [ 77,  49, 109],
#          ...,
#          [ 61,  38,  91],
#          [ 63,  39,  92],
#          [ 51,  29,  78]],
#
#         [[ 73,  45, 105],
#          [ 72,  44, 104],
#          [ 79,  51, 112],
#          ...,
#          [ 62,  39,  91],
#          [ 61,  38,  90],
#          [ 53,  31,  79]]],
#
#
#        [[[187, 133, 126],
#          [203, 159, 153],
#          [173, 140, 135],
#          ...,
#          [ 97,  91,  93],
#          [ 87,  86,  94],
#          [ 88,  83,  86]],
#
#         [[227, 174, 167],
#          [157, 114, 107],
#          [168, 133, 129],
#          ...,
#          [100,  95,  96],
#          [ 97,  95, 100],
#          [ 81,  81,  91]],
#
#         [[212, 164, 156],
#          [171, 127, 121],
#          [167, 129, 125],
#          ...,
#          [104,  99, 101],
#          [ 99,  95,  97],
#          [ 73,  77,  87]],
#
#         ...,
#
#         [[163, 163, 163],
#          [108, 106, 118],
#          [135, 139, 144],
#          ...,
#          [ 21,  24,  29],
#          [ 22,  25,  30],
#          [ 28,  32,  37]],
#
#         [[141, 139, 139],
#          [130, 128, 134],
#          [120, 123, 128],
#          ...,
#          [ 17,  20,  25],
#          [ 23,  26,  31],
#          [ 25,  29,  34]],
#
#         [[164, 160, 159],
#          [151, 149, 148],
#          [151, 151, 156],
#          ...,
#          [ 13,  16,  21],
#          [ 19,  22,  27],
#          [ 16,  24,  28]]],
#
#
#        ...,
#
#
#        [[[212, 212, 194],
#          [212, 212, 194],
#          [213, 213, 197],
#          ...,
#          [ 91,  95, 139],
#          [ 98, 100, 144],
#          [108, 107, 151]],
#
#         [[210, 210, 192],
#          [215, 215, 197],
#          [216, 216, 201],
#          ...,
#          [ 98, 107, 151],
#          [108, 114, 159],
#          [114, 119, 164]],
#
#         [[214, 214, 196],
#          [214, 214, 196],
#          [214, 213, 198],
#          ...,
#          [ 98, 109, 156],
#          [104, 114, 161],
#          [116, 122, 169]],
#
#         ...,
#
#         [[127, 153, 159],
#          [129, 155, 161],
#          [126, 152, 158],
#          ...,
#          [  4,   6,   7],
#          [ 50,  67,  68],
#          [ 73,  98, 102]],
#
#         [[124, 150, 156],
#          [129, 155, 161],
#          [128, 154, 160],
#          ...,
#          [  5,   5,   6],
#          [ 11,  24,  26],
#          [ 75,  97, 102]],
#
#         [[125, 151, 157],
#          [128, 154, 160],
#          [124, 150, 156],
#          ...,
#          [  1,   0,   1],
#          [  0,   4,   6],
#          [ 85, 105, 108]]],
#
#
#        [[[196, 255, 239],
#          [216, 248, 238],
#          [227, 245, 244],
#          ...,
#          [240, 241, 237],
#          [238, 238, 234],
#          [240, 235, 232]],
#
#         [[190, 248, 231],
#          [223, 253, 246],
#          [227, 246, 244],
#          ...,
#          [226, 227, 224],
#          [235, 235, 231],
#          [223, 218, 215]],
#
#         [[146, 201, 184],
#          [158, 193, 183],
#          [223, 244, 242],
#          ...,
#          [234, 235, 231],
#          [233, 233, 229],
#          [231, 226, 223]],
#
#         ...,
#
#         [[113, 130, 113],
#          [ 87, 106,  89],
#          [ 91, 115,  97],
#          ...,
#          [ 83,  95,  79],
#          [ 44,  69,  48],
#          [ 80, 107,  94]],
#
#         [[110, 126, 109],
#          [113, 132, 115],
#          [ 69,  93,  75],
#          ...,
#          [ 79, 101,  83],
#          [ 40,  71,  49],
#          [ 42,  55,  49]],
#
#         [[ 97, 114, 100],
#          [ 93, 111,  94],
#          [ 83, 103,  82],
#          ...,
#          [ 82, 102,  83],
#          [ 82, 101,  82],
#          [ 75,  86,  66]]],
#
#
#        [[[144, 143, 139],
#          [144, 143, 139],
#          [142, 141, 137],
#          ...,
#          [165, 164, 160],
#          [162, 161, 157],
#          [168, 163, 160]],
#
#         [[144, 143, 139],
#          [144, 143, 139],
#          [142, 141, 137],
#          ...,
#          [162, 162, 158],
#          [165, 163, 159],
#          [169, 165, 159]],
#
#         [[146, 145, 141],
#          [143, 142, 138],
#          [144, 143, 139],
#          ...,
#          [161, 160, 156],
#          [166, 165, 159],
#          [173, 171, 161]],
#
#         ...,
#
#         [[176, 181, 179],
#          [180, 185, 183],
#          [172, 177, 175],
#          ...,
#          [171, 176, 174],
#          [170, 175, 173],
#          [162, 168, 165]],
#
#         [[160, 165, 163],
#          [174, 179, 177],
#          [173, 178, 175],
#          ...,
#          [168, 173, 171],
#          [163, 168, 166],
#          [172, 177, 176]],
#
#         [[175, 178, 176],
#          [172, 175, 173],
#          [176, 179, 177],
#          ...,
#          [170, 175, 173],
#          [169, 174, 173],
#          [170, 175, 174]]]], dtype=uint8)

# %%
y
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
# Normalization is a scaling technique in which values are shifted and rescaled 
# so that they end up ranging between 0 and 1. It is also known as Min-Max scaling
X = X/255 # feature scaling

# %%
X
# Out:
# array([[[[0.38823529, 0.37254902, 0.56862745],
#          [0.39215686, 0.37647059, 0.56862745],
#          [0.4       , 0.38431373, 0.57254902],
#          ...,
#          [0.38823529, 0.42352941, 0.67058824],
#          [0.38431373, 0.41960784, 0.66666667],
#          [0.38039216, 0.41568627, 0.6627451 ]],
#
#         [[0.37647059, 0.36470588, 0.57647059],
#          [0.38039216, 0.37254902, 0.57647059],
#          [0.38431373, 0.37647059, 0.58039216],
#          ...,
#          [0.37254902, 0.41568627, 0.65882353],
#          [0.37254902, 0.41568627, 0.65882353],
#          [0.37254902, 0.41568627, 0.65882353]],
#
#         [[0.35294118, 0.36078431, 0.58431373],
#          [0.35686275, 0.36470588, 0.59215686],
#          [0.36470588, 0.36862745, 0.59215686],
#          ...,
#          [0.36078431, 0.41176471, 0.6627451 ],
#          [0.36862745, 0.41568627, 0.66666667],
#          [0.36862745, 0.41568627, 0.66666667]],
#
#         ...,
#
#         [[0.44313725, 0.48235294, 0.57647059],
#          [0.45098039, 0.49019608, 0.58431373],
#          [0.43921569, 0.47843137, 0.57254902],
#          ...,
#          [0.4       , 0.41960784, 0.5254902 ],
#          [0.34901961, 0.37647059, 0.45490196],
#          [0.25882353, 0.29019608, 0.36078431]],
#
#         [[0.43529412, 0.4745098 , 0.56862745],
#          [0.41960784, 0.45882353, 0.55294118],
#          [0.42745098, 0.46666667, 0.56078431],
#          ...,
#          [0.42352941, 0.43137255, 0.54901961],
#          [0.43921569, 0.45490196, 0.55294118],
#          [0.39215686, 0.41568627, 0.49411765]],
#
#         [[0.42352941, 0.4627451 , 0.55686275],
#          [0.41176471, 0.45098039, 0.54509804],
#          [0.41960784, 0.45882353, 0.55294118],
#          ...,
#          [0.41960784, 0.43921569, 0.56078431],
#          [0.43921569, 0.46666667, 0.56470588],
#          [0.39607843, 0.43137255, 0.51372549]]],
#
#
#        [[[0.22352941, 0.25882353, 0.29019608],
#          [0.22352941, 0.25882353, 0.29019608],
#          [0.22352941, 0.25882353, 0.29019608],
#          ...,
#          [0.0627451 , 0.08627451, 0.11372549],
#          [0.07843137, 0.10196078, 0.12941176],
#          [0.0627451 , 0.08627451, 0.11372549]],
#
#         [[0.16470588, 0.2       , 0.23529412],
#          [0.16470588, 0.2       , 0.23529412],
#          [0.16470588, 0.2       , 0.23529412],
#          ...,
#          [0.12156863, 0.14509804, 0.17254902],
#          [0.12156863, 0.14509804, 0.17254902],
#          [0.11764706, 0.14117647, 0.16862745]],
#
#         [[0.10588235, 0.1372549 , 0.18823529],
#          [0.10588235, 0.1372549 , 0.18823529],
#          [0.10588235, 0.1372549 , 0.18823529],
#          ...,
#          [0.10196078, 0.1254902 , 0.15294118],
#          [0.07843137, 0.10196078, 0.12941176],
#          [0.09019608, 0.11372549, 0.14117647]],
#
#         ...,
#
#         [[0.47843137, 0.51372549, 0.65098039],
#          [0.41176471, 0.44705882, 0.59215686],
#          [0.37647059, 0.40784314, 0.56862745],
#          ...,
#          [0.35686275, 0.38431373, 0.45882353],
#          [0.37647059, 0.40392157, 0.47843137],
#          [0.34117647, 0.36862745, 0.44313725]],
#
#         [[0.46666667, 0.51372549, 0.65882353],
#          [0.41960784, 0.4627451 , 0.61176471],
#          [0.36470588, 0.40784314, 0.57254902],
#          ...,
#          [0.3254902 , 0.34901961, 0.42352941],
#          [0.36078431, 0.38431373, 0.45882353],
#          [0.36470588, 0.38823529, 0.4627451 ]],
#
#         [[0.43137255, 0.49411765, 0.64705882],
#          [0.42745098, 0.49019608, 0.64705882],
#          [0.37254902, 0.43137255, 0.6       ],
#          ...,
#          [0.16862745, 0.18823529, 0.2627451 ],
#          [0.2745098 , 0.29019608, 0.36470588],
#          [0.32941176, 0.34509804, 0.41960784]]],
#
#
#        [[[0.2627451 , 0.41960784, 0.58431373],
#          [0.16078431, 0.30980392, 0.49411765],
#          [0.11764706, 0.25490196, 0.46666667],
#          ...,
#          [0.30196078, 0.25098039, 0.21568627],
#          [0.40784314, 0.34509804, 0.29803922],
#          [0.61960784, 0.55686275, 0.50588235]],
#
#         [[0.24705882, 0.4       , 0.57254902],
#          [0.19215686, 0.3372549 , 0.5372549 ],
#          [0.10196078, 0.23529412, 0.46666667],
#          ...,
#          [0.32156863, 0.24705882, 0.21568627],
#          [0.40392157, 0.31764706, 0.2745098 ],
#          [0.51372549, 0.42352941, 0.36078431]],
#
#         [[0.16862745, 0.31764706, 0.50588235],
#          [0.14117647, 0.28235294, 0.49411765],
#          [0.09803922, 0.22745098, 0.4745098 ],
#          ...,
#          [0.24313725, 0.18823529, 0.15294118],
#          [0.34509804, 0.27843137, 0.23529412],
#          [0.4745098 , 0.41176471, 0.36078431]],
#
#         ...,
#
#         [[0.77254902, 0.77254902, 0.65490196],
#          [0.66666667, 0.65882353, 0.53333333],
#          [0.63137255, 0.61568627, 0.47843137],
#          ...,
#          [0.90196078, 0.85098039, 0.83921569],
#          [0.85882353, 0.85098039, 0.80392157],
#          [0.65490196, 0.71372549, 0.63137255]],
#
#         [[0.78823529, 0.78039216, 0.65098039],
#          [0.67843137, 0.6627451 , 0.5254902 ],
#          [0.6745098 , 0.64705882, 0.49803922],
#          ...,
#          [0.88627451, 0.88235294, 0.84705882],
#          [0.88627451, 0.87843137, 0.81568627],
#          [0.8627451 , 0.87058824, 0.80784314]],
#
#         [[0.88235294, 0.8745098 , 0.7372549 ],
#          [0.61568627, 0.6       , 0.45098039],
#          [0.65882353, 0.63137255, 0.47843137],
#          ...,
#          [0.72941176, 0.80784314, 0.72156863],
#          [0.67058824, 0.77254902, 0.65490196],
#          [0.69803922, 0.76078431, 0.66666667]]],
#
#
#        ...,
#
#
#        [[[0.03921569, 0.04313725, 0.02745098],
#          [0.03921569, 0.03921569, 0.02352941],
#          [0.04313725, 0.04705882, 0.03137255],
#          ...,
#          [0.45882353, 0.45882353, 0.43529412],
#          [0.49411765, 0.49803922, 0.45882353],
#          [0.57254902, 0.57254902, 0.55294118]],
#
#         [[0.03529412, 0.03529412, 0.02352941],
#          [0.03137255, 0.03529412, 0.01960784],
#          [0.03529412, 0.03921569, 0.02352941],
#          ...,
#          [0.46666667, 0.46666667, 0.44313725],
#          [0.49019608, 0.49803922, 0.45882353],
#          [0.56862745, 0.56470588, 0.54901961]],
#
#         [[0.02745098, 0.03137255, 0.01568627],
#          [0.02745098, 0.03529412, 0.01568627],
#          [0.03529412, 0.03921569, 0.02352941],
#          ...,
#          [0.46666667, 0.46666667, 0.44313725],
#          [0.49803922, 0.50196078, 0.4627451 ],
#          [0.56078431, 0.55686275, 0.54117647]],
#
#         ...,
#
#         [[0.19215686, 0.18039216, 0.16470588],
#          [0.24705882, 0.25098039, 0.22352941],
#          [0.20392157, 0.17647059, 0.14509804],
#          ...,
#          [0.60784314, 0.52156863, 0.69019608],
#          [0.76470588, 0.75686275, 0.83137255],
#          [0.88235294, 0.88627451, 0.92941176]],
#
#         [[0.25490196, 0.24313725, 0.22352941],
#          [0.20392157, 0.21568627, 0.18039216],
#          [0.2       , 0.18039216, 0.14117647],
#          ...,
#          [0.76862745, 0.72156863, 0.87058824],
#          [0.90588235, 0.94117647, 0.97254902],
#          [0.95294118, 0.94509804, 0.95294118]],
#
#         [[0.20392157, 0.20392157, 0.18039216],
#          [0.22745098, 0.21176471, 0.17254902],
#          [0.20784314, 0.17254902, 0.12156863],
#          ...,
#          [0.95294118, 0.94901961, 1.        ],
#          [0.9254902 , 0.92941176, 0.96862745],
#          [0.96862745, 0.96078431, 0.98431373]]],
#
#
#        [[[0.36470588, 0.42352941, 0.40784314],
#          [0.38039216, 0.43921569, 0.42352941],
#          [0.36470588, 0.42352941, 0.40784314],
#          ...,
#          [0.45490196, 0.5372549 , 0.56862745],
#          [0.43137255, 0.51372549, 0.54509804],
#          [0.41568627, 0.49803922, 0.52941176]],
#
#         [[0.41568627, 0.4745098 , 0.45882353],
#          [0.36078431, 0.41960784, 0.40392157],
#          [0.38039216, 0.43921569, 0.42352941],
#          ...,
#          [0.43921569, 0.52156863, 0.55294118],
#          [0.42352941, 0.50588235, 0.5372549 ],
#          [0.40392157, 0.48627451, 0.51764706]],
#
#         [[0.40784314, 0.46666667, 0.45098039],
#          [0.35686275, 0.41960784, 0.40392157],
#          [0.33333333, 0.39215686, 0.37647059],
#          ...,
#          [0.43921569, 0.52156863, 0.55294118],
#          [0.43921569, 0.52156863, 0.55294118],
#          [0.41568627, 0.49803922, 0.52941176]],
#
#         ...,
#
#         [[0.41960784, 0.53333333, 0.58823529],
#          [0.44313725, 0.54509804, 0.6       ],
#          [0.44313725, 0.5254902 , 0.58823529],
#          ...,
#          [0.74509804, 0.85490196, 0.89803922],
#          [0.76078431, 0.87058824, 0.91372549],
#          [0.72941176, 0.84313725, 0.86666667]],
#
#         [[0.41176471, 0.5254902 , 0.58039216],
#          [0.45098039, 0.55294118, 0.60784314],
#          [0.47058824, 0.55294118, 0.61176471],
#          ...,
#          [0.71764706, 0.83137255, 0.88627451],
#          [0.7372549 , 0.83137255, 0.88627451],
#          [0.72156863, 0.83137255, 0.8745098 ]],
#
#         [[0.44313725, 0.54509804, 0.59215686],
#          [0.4627451 , 0.55686275, 0.60392157],
#          [0.48235294, 0.55686275, 0.60784314],
#          ...,
#          [0.70980392, 0.82745098, 0.87058824],
#          [0.66666667, 0.78431373, 0.82745098],
#          [0.65098039, 0.76078431, 0.80392157]]],
#
#
#        [[[0.22352941, 0.34509804, 0.56078431],
#          [0.29411765, 0.40392157, 0.58431373],
#          [0.45098039, 0.51372549, 0.61960784],
#          ...,
#          [0.16862745, 0.34901961, 0.53333333],
#          [0.26666667, 0.36078431, 0.5254902 ],
#          [0.25490196, 0.38823529, 0.52941176]],
#
#         [[0.30980392, 0.41568627, 0.61568627],
#          [0.31764706, 0.43529412, 0.63529412],
#          [0.43529412, 0.52156863, 0.66666667],
#          ...,
#          [0.14901961, 0.31764706, 0.49019608],
#          [0.2745098 , 0.36078431, 0.51372549],
#          [0.24705882, 0.38039216, 0.52941176]],
#
#         [[0.25882353, 0.34901961, 0.5254902 ],
#          [0.22745098, 0.35294118, 0.56078431],
#          [0.30588235, 0.43529412, 0.61960784],
#          ...,
#          [0.15294118, 0.30588235, 0.4627451 ],
#          [0.28235294, 0.36470588, 0.51372549],
#          [0.24313725, 0.38039216, 0.54901961]],
#
#         ...,
#
#         [[0.22352941, 0.16078431, 0.16470588],
#          [0.23921569, 0.17647059, 0.18039216],
#          [0.22745098, 0.16470588, 0.16862745],
#          ...,
#          [0.31764706, 0.20392157, 0.20784314],
#          [0.30588235, 0.20392157, 0.20392157],
#          [0.27843137, 0.19607843, 0.19215686]],
#
#         [[0.23137255, 0.16862745, 0.17254902],
#          [0.22745098, 0.16470588, 0.16862745],
#          [0.22745098, 0.16470588, 0.16862745],
#          ...,
#          [0.32156863, 0.21960784, 0.21960784],
#          [0.30196078, 0.2       , 0.2       ],
#          [0.28627451, 0.19215686, 0.19215686]],
#
#         [[0.22352941, 0.16078431, 0.16470588],
#          [0.23529412, 0.17254902, 0.17647059],
#          [0.22352941, 0.16078431, 0.16470588],
#          ...,
#          [0.30196078, 0.2       , 0.2       ],
#          [0.31372549, 0.21176471, 0.21176471],
#          [0.29411765, 0.2       , 0.2       ]]]])

# %%
X.shape
# Out:
# (25000, 96, 96, 3)

# %%
# now design CNN Model
model = tf.keras.models.Sequential([# Convolutional layer 1
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu', input_shape=(96, 96, 3)),
                                    tf.keras.layers.MaxPooling2D(2, 2),

                                    # Convolutional layer 2
                                    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
                                    tf.keras.layers.MaxPooling2D(2, 2),

                                    # Flatten layer - Output of convolution
                                    tf.keras.layers.Flatten(),
                
                                    # Hidden layer
                                    tf.keras.layers.Dense(128, activation=tf.nn.relu),

                                    # Output layer
                                    tf.keras.layers.Dense(2, activation=tf.nn.softmax)])

# %%
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 94, 94, 64)        1792
#
#  max_pooling2d (MaxPooling2D  (None, 47, 47, 64)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 45, 45, 64)        36928
#
#  max_pooling2d_1 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 2)                 258
#
# =================================================================
# Total params: 4,004,034
# Trainable params: 4,004,034
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(X, y, epochs=5)
# Out:
# Epoch 1/5
# 782/782 [==============================] - 179s 203ms/step - loss: 0.6433 - accuracy: 0.6303
# Epoch 2/5
# 782/782 [==============================] - 157s 201ms/step - loss: 0.5092 - accuracy: 0.7504
# Epoch 3/5
# 782/782 [==============================] - 156s 199ms/step - loss: 0.4030 - accuracy: 0.8160
# Epoch 4/5
# 782/782 [==============================] - 156s 200ms/step - loss: 0.2812 - accuracy: 0.8799
# Epoch 5/5
# 782/782 [==============================] - 156s 200ms/step - loss: 0.1409 - accuracy: 0.9444

# %%
# Model Evaluation
scores = model.evaluate(X, y)
# Out:
# 782/782 [==============================] - 80s 79ms/step - loss: 0.0539 - accuracy: 0.9891

# %%
model.save("model.h5")
